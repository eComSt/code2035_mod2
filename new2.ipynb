# %%
import vk_api
from bs4 import BeautifulSoup
from datetime import datetime

with open("key.txt",'r') as file:
    token = file.read()

vk = vk_api.VkApi(token=token)

while True:
    messages = vk.method("messages.getConversations",{"count":20,"filter":"unanswered"})
    if messages["count"]>=1:
        print(messages)
# Out:
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# ...
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
# {'count': 1, 'unread_count': 1, 'items': [{'conversation': {'peer': {'id': 754952176, 'type': 'user', 'local_id': 754952176}, 'last_message_id': 2, 'in_read': 0, 'out_read': 2, 'last_conversation_message_id': 1, 'in_read_cmid': 0, 'out_read_cmid': 1, 'unread_count': 1, 'is_marked_unread': False, 'important': False, 'unanswered': True, 'can_write': {'allowed': True}}, 'last_message': {'date': 1679752348, 'from_id': 754952176, 'id': 2, 'out': 0, 'attachments': [], 'conversation_message_id': 1, 'fwd_messages': [], 'important': False, 'is_hidden': False, 'peer_id': 754952176, 'random_id': 0, 'text': 'Здравствуйте. 👋\n\n😉 https://vk.cc/cmAxgs\n\n🥳 У Вас новое сообщество, хотим предложить помощь.\n\n✔️ 1000 Подписчиков на сообщество — 250 рублей в течении 40 минут.\n\n✔️ Найти целивую аудиторию, клиентов с помощью рассылки в течении 4 часов.\nВся работа на нас, предоставляем полную отчётность.'}}]}
